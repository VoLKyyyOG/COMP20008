# %%
# datasets
import os

files = os.listdir()
files = list(filter(lambda x: x.endswith('.csv'), files))

files
# Out:
# ['data5728559800236095482.csv', 'data8220457880066555889.csv']

# %%
import pandas as pd
import matplotlib.pyplot as plt

df1 = pd.read_csv(files[0])
df2 = pd.read_csv(files[1])

# %%
df1.tail()
# Out:
#    significance   numeric        lga_name06   ci_high   vic_ave   lga_code06  \
# 74         none      52.6      Wodonga (RC)      59.8      50.7        27170
# 75         none      52.6       Wyndham (C)      59.8      50.7        27260
# 76       better      67.7         Yarra (C)      74.8      50.7        27350
# 77         none      50.9  Yarra Ranges (S)      57.7      50.7        27450
# 78         none      44.5  Yarriambiack (S)      53.1      50.7        27630
#
#      ci_low
# 74     45.3
# 75     45.3
# 76     59.7
# 77     44.1
# 78     36.2

# %%
# looks like the columns have a space...
df1.columns
# Out:
# Index(['significance', ' numeric', ' lga_name06', ' ci_high', ' vic_ave',
#        ' lga_code06', ' ci_low'],
#       dtype='object')

# %%
# so let's remmove them
df1.columns = [i.strip() for i in df1.columns]

# %%
df2.tail()
# Out:
#     ppl_reporting_fair_or_poor_hlth_status_rank  \
# 74                                           63
# 75                                           21
# 76                                           43
# 77                                           37
# 78                                            2
#
#      ppl_reporting_being_obese_perc   females_reporting_being_obese_perc  \
# 74                             20.3                                 20.4
# 75                             25.1                                 26.9
# 76                             12.1                                  9.1
# 77                             16.4                                 15.7
# 78                             25.2                                 25.0
#
#      gp_attendances_per_1000_males_rank  \
# 74                                   44
# 75                                   25
# 76                                   72
# 77                                   49
# 78                                    4
#
#      proj_ann_chg_inpatient_separts_btwn_2014_15_and_2026_27_perc  \
# 74                                                3.2
# 75                                                5.3
# 76                                                3.4
# 77                                                2.7
# 78                                               -0.8
#
#      specialist_attendances_per_1000_pop_rank  \
# 74                                         50
# 75                                         79
# 76                                         31
# 77                                         33
# 78                                         42
#
#      acsc_pph_separts_for_all_conds_per_1000_pop_rank  \
# 74                                                 76
# 75                                                 67
# 76                                                 74
# 77                                                 50
# 78                                                 10
#
#      cervical_cancer_screening_participation_rank  \
# 74                                             17
# 75                                             78
# 76                                             16
# 77                                             21
# 78                                             71
#
#      disability_sup_pension_recipients_per_1000_eligible_pop  \
# 74                                               64.7
# 75                                               33.6
# 76                                               42.2
# 77                                               49.6
# 78                                              129.2
#
#      chn_attd_3_5_yr_old_maternal_and_child_hlth_checks_perc  ...  \
# 74                                               65.8         ...
# 75                                               57.0         ...
# 76                                               70.6         ...
# 77                                               60.1         ...
# 78                                               98.0         ...
#
#     households_with_mortgage_stress_rank  \
# 74                                    67
# 75                                    24
# 76                                    79
# 77                                    41
# 78                                    46
#
#      avg_lng_of_stay_days_all_acsc_pph_separts  \
# 74                                         5.1
# 75                                         3.5
# 76                                         4.0
# 77                                         4.0
# 78                                         4.0
#
#     ppl_reporting_heart_disease_rank   new_settler_arrivals_per_100000_pop  \
# 74                                 5                                 146.9
# 75                                68                                1185.7
# 76                                39                                 662.4
# 77                                48                                 158.6
# 78                                 3                                  14.5
#
#      journeys_to_work_which_are_by_public_transport_rank  \
# 74                                                 54
# 75                                                 19
# 76                                                  2
# 77                                                 30
# 78                                                 76
#
#      ppl_who_did_not_complete_yr_12_rank  proj_ann_pop_chg_perc_2014_2024  \
# 74                                    35                              1.8
# 75                                    61                              4.0
# 76                                    75                              2.2
# 77                                    49                              0.8
# 78                                     2                             -0.9
#
#      chn_dev_vul_in_one_or_more_doms_perc   male_life_expectancy  \
# 74                                   22.9                   80.3
# 75                                   25.0                   80.1
# 76                                   18.3                   79.6
# 77                                   16.8                   80.1
# 78                                   26.9                   78.1
#
#     new_dwellings_approved_per_1000_pop_rank
# 74                                        22
# 75                                         7
# 76                                         6
# 77                                        54
# 78                                        77
#
# [5 rows x 402 columns]

# %%
df2.columns
# Out:
# Index(['ppl_reporting_fair_or_poor_hlth_status_rank',
#        ' ppl_reporting_being_obese_perc',
#        ' females_reporting_being_obese_perc',
#        ' gp_attendances_per_1000_males_rank',
#        ' proj_ann_chg_inpatient_separts_btwn_2014_15_and_2026_27_perc',
#        ' specialist_attendances_per_1000_pop_rank',
#        ' acsc_pph_separts_for_all_conds_per_1000_pop_rank',
#        ' cervical_cancer_screening_participation_rank',
#        ' disability_sup_pension_recipients_per_1000_eligible_pop',
#        ' chn_attd_3_5_yr_old_maternal_and_child_hlth_checks_perc',
#        ...
#        ' households_with_mortgage_stress_rank',
#        ' avg_lng_of_stay_days_all_acsc_pph_separts',
#        ' ppl_reporting_heart_disease_rank',
#        ' new_settler_arrivals_per_100000_pop',
#        ' journeys_to_work_which_are_by_public_transport_rank',
#        ' ppl_who_did_not_complete_yr_12_rank',
#        ' proj_ann_pop_chg_perc_2014_2024',
#        ' chn_dev_vul_in_one_or_more_doms_perc', ' male_life_expectancy',
#        ' new_dwellings_approved_per_1000_pop_rank'],
#       dtype='object', length=402)

# %%
# likewise with df2
df2.columns = [i.strip() for i in df2.columns]

# %%
# find the blood pressure attribute(s)
blood_pressure_cols = [i for i in df2.columns if 'blood' in i.lower()]
blood_pressure_cols
# Out:
# ['ppl_reporting_high_blood_pressure_perc',
#  'ppl_reporting_high_blood_pressure_rank']

# %%
# merge datasets (add the lga_code on the df2 side)
df = df2[blood_pressure_cols + ['lga_code']].merge(df1, left_on='lga_code', right_on='lga_code06')
df.tail()
# Out:
#     ppl_reporting_high_blood_pressure_perc  \
# 74                                    28.1
# 75                                    29.6
# 76                                    22.5
# 77                                    23.6
# 78                                    28.3
#
#     ppl_reporting_high_blood_pressure_rank  lga_code significance  numeric  \
# 74                                      29     27170         none     52.6
# 75                                      12     27260         none     52.6
# 76                                      64     27350       better     67.7
# 77                                      57     27450         none     50.9
# 78                                      27     27630         none     44.5
#
#           lga_name06  ci_high  vic_ave  lga_code06  ci_low
# 74      Wodonga (RC)     59.8     50.7       27170    45.3
# 75       Wyndham (C)     59.8     50.7       27260    45.3
# 76         Yarra (C)     74.8     50.7       27350    59.7
# 77  Yarra Ranges (S)     57.7     50.7       27450    44.1
# 78  Yarriambiack (S)     53.1     50.7       27630    36.2

# %%
df.set_index('lga_code', inplace=True)
